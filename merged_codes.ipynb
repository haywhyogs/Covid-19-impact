# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
style.use('ggplot')
# %matplotlib inline
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('merged_data.csv')
df.head()
# Out:
#    Date  Country  11 Corporate managers and directors  \
# 0  2004  England                              1689500
# 1  2005  England                              1697000
# 2  2006  England                              1730900
# 3  2007  England                              1794600
# 4  2008  England                              1828700
#
#    21 Science, research, engineering and technology professionals  \
# 0                                            1110500
# 1                                            1161800
# 2                                            1190900
# 3                                            1198600
# 4                                            1232800
#
#    22 Health professionals  23 Teaching and educational professionals  \
# 0                   806400                                    1058700
# 1                   840700                                    1079900
# 2                   883100                                    1107600
# ...

# %%
wales_df = df[df.Country == 'Wales']

# %%
wales_df.head()
# Out:
#     Date Country  11 Corporate managers and directors  \
# 18  2004   Wales                                73200
# 19  2005   Wales                                71200
# 20  2006   Wales                                77000
# 21  2007   Wales                                83800
# 22  2008   Wales                                80000
#
#     21 Science, research, engineering and technology professionals  \
# 18                                              44200
# 19                                              45500
# 20                                              46600
# 21                                              50900
# 22                                              50900
#
#     22 Health professionals  23 Teaching and educational professionals  \
# 18                    50900                                      61200
# 19                    53400                                      62700
# 20                    53900                                      62500
# ...

# %%
sns.lineplot(x = 'Date', y = '42 Secretarial and related occupations', data = wales_df)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='42 Secretarial and related occupations'>

# %%
sns.lineplot(x = 'Date', y = '51 Skilled agricultural and related trades', data = wales_df)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='51 Skilled agricultural and related trades'>

# %%
sns.lineplot(x = 'Date', y = '53 Skilled construction and building trades', data = wales_df)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='53 Skilled construction and building trades'>

# %%
sns.lineplot(x = 'Date', y = '61 Caring personal service occupations', data = wales_df)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='61 Caring personal service occupations'>

# %%
sns.lineplot(x = 'Date', y = '62 Leisure, travel and related personal service occupations', data = wales_df)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='62 Leisure, travel and related personal service occupations'>

# %%
sns.lineplot(x = 'Date', y = '11 Corporate managers and directors', data = wales_df)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='11 Corporate managers and directors'>

# %%
sns.lineplot(x = 'Date', y = '21 Science, research, engineering and technology professionals', data = wales_df)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='21 Science, research, engineering and technology professionals'>

# %%
sns.lineplot(x = 'Date', y = '22 Health professionals', data = wales_df)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='22 Health professionals'>

# %%
sns.lineplot(x = 'Date', y = '23 Teaching and educational professionals', data = wales_df)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='23 Teaching and educational professionals'>

# %%
sns.lineplot(x = 'Date', y = '24 Business, media and public service professionals', data = wales_df)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='24 Business, media and public service professionals'>

# %%
sns.lineplot(x = 'Date', y = '33 Protective service occupations', data = wales_df)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='33 Protective service occupations'>

# %%
sns.lineplot(x = 'Date', y = '34 Culture, media and sports occupations', data = wales_df)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='34 Culture, media and sports occupations'>

# %%
m = ['21 Science, research, engineering and technology professionals','11 Corporate managers and directors','41 Administrative occupations','22 Health professionals','61 Caring personal service occupations']
n = ['51 Skilled agricultural and related trades','23 Teaching and educational professionals','24 Business, media and public service professionals','53 Skilled construction and building trades','62 Leisure, travel and related personal service occupations']
o = ['33 Protective service occupations','34 Culture, media and sports occupations','42 Secretarial and related occupations','81 Process, plant and machine operatives','82 Transport and mobile machine drivers and operatives']

# %%
wales_df.plot(x = 'Date', y = m , kind = 'line', marker = '+', ms = 10, figsize = (20,10))
plt.ylim([40000, 130000])

# %%
wales_df.plot(x = 'Date', y = o , kind = 'line', marker = '+', ms = 10, figsize = (20,10))
#plt.ylim([40000, 130000])

# %%
wales_df.plot(x = 'Date', y = n , kind = 'line', marker = '+', ms = 10, figsize = (20,10))
#plt.ylim([40000, 130000])

# %%
england_df = df[df.Country == 'England']

# %%
p = ['21 Science, research, engineering and technology professionals','11 Corporate managers and directors','41 Administrative occupations','22 Health professionals','61 Caring personal service occupations']
q = ['51 Skilled agricultural and related trades','23 Teaching and educational professionals','24 Business, media and public service professionals','53 Skilled construction and building trades','62 Leisure, travel and related personal service occupations']
r = ['33 Protective service occupations','34 Culture, media and sports occupations','42 Secretarial and related occupations','81 Process, plant and machine operatives','82 Transport and mobile machine drivers and operatives']

# %%
wales_df.to_csv('wales.csv',index=False)

# %%
england_df.plot(x = 'Date', y = p , kind = 'line', marker = '+', ms = 10, figsize = (20,10))
#plt.ylim([40000, 130000])

# %%
england_df.plot(x = 'Date', y = q , kind = 'line', marker = '+', ms = 10, figsize = (20,10))
#plt.ylim([40000, 130000])

# %%
df.dtypes

# %%
england_df.plot(x = 'Date', y = r , kind = 'line', marker = '+', ms = 10, figsize = (20,10))
#plt.ylim([40000, 130000])

# %%
health = df[['Date','Country','22 Health professionals']]
health.head()

# %%
scotland_df = df[df.Country == 'Scotland']

# %%
a = ['21 Science, research, engineering and technology professionals','11 Corporate managers and directors','41 Administrative occupations','22 Health professionals','61 Caring personal service occupations']
b = ['51 Skilled agricultural and related trades','23 Teaching and educational professionals','24 Business, media and public service professionals','53 Skilled construction and building trades','62 Leisure, travel and related personal service occupations']
c = ['33 Protective service occupations','34 Culture, media and sports occupations','42 Secretarial and related occupations','81 Process, plant and machine operatives','82 Transport and mobile machine drivers and operatives']

# %%
scotland_df.plot(x = 'Date', y = a , kind = 'line', marker = '+', ms = 10, figsize = (20,10))
#plt.ylim([40000, 130000])

# %%
scotland_df.plot(x = 'Date', y = b , kind = 'line', marker = '+', ms = 10, figsize = (20,10))

# %%
scotland_df.plot(x = 'Date', y = c , kind = 'line', marker = '+', ms = 10, figsize = (20,10))

# %%
northern_ireland = df[df.Country == 'Northern Ireland']

# %%
d = ['21 Science, research, engineering and technology professionals','11 Corporate managers and directors','41 Administrative occupations','22 Health professionals','61 Caring personal service occupations']
e = ['51 Skilled agricultural and related trades','23 Teaching and educational professionals','24 Business, media and public service professionals','53 Skilled construction and building trades','62 Leisure, travel and related personal service occupations']
f = ['33 Protective service occupations','34 Culture, media and sports occupations','42 Secretarial and related occupations','81 Process, plant and machine operatives','82 Transport and mobile machine drivers and operatives']

# %%
northern_ireland.plot(x = 'Date', y = d , kind = 'line', marker = '+', ms = 10, figsize = (20,10))

northern_ireland.plot(x = 'Date', y = e , kind = 'line', marker = '+', ms = 10, figsize = (20,10))

northern_ireland.plot(x = 'Date', y = f , kind = 'line', marker = '+', ms = 10, figsize = (20,10))

# %%
northern_ireland.plot(x = d, y = 'Date' , kind = 'line', marker = '+', ms = 10, figsize = (20,10))

# %%
health_wales = health[health.Country == 'Wales']
health_wales.tail()

# %%
health_england = health[health.Country == 'England']
health_england.head()

# %%
health_scotland = health[health.Country == 'Scotland']
health_scotland.head()

# %%
health_ireland = health[health.Country == 'Northern Ireland']
health_ireland.head()

# %%
#df.style.background_gradient(cmap = 'Reds')

# %%
country_with_most_jobs = df.groupby('Date')['22 Health professionals','21 Science, research, engineering and technology professionals','61 Caring personal service occupations','62 Leisure, travel and related personal service occupations','33 Protective service occupations'].sum()
country_with_most_jobs.head()

# %%
health_wales = health[health.Country == 'Wales']

# %%
ax = sns.lineplot(x = 'Date', y = '22 Health professionals', data = health, hue='Country')

# %%
ax = sns.barplot(x = 'Date', y = '22 Health professionals', data = health, hue='Country')

# %%
ax = sns.lineplot(x = 'Date', y = '22 Health professionals', data = health_wales, hue='Country')

# %%
sns.set(rc={'figure.figsize':(12,10)})
ax = sns.lineplot(x = 'Date', y = '22 Health professionals', data = df, hue='Country')

# %%
ax = sns.lineplot(x = 'Date', y = '22 Health professionals', data = health_england, hue='Country')

# %%
ax = sns.barplot(x = 'Date', y = '22 Health professionals', data = health_wales, hue='Country')

# %%
ax = sns.barplot(x = 'Date', y = '22 Health professionals', data = df, hue='Country')

# %%
ax = sns.barplot(x = 'Date', y = '22 Health professionals', data = health_england, hue='Country')

# %%
ax = sns.barplot(x = 'Date', y = '22 Health professionals', data = health_scotland, hue='Country')

# %%
ax = sns.barplot(x = 'Date', y = '22 Health professionals', data = health_ireland, hue='Country')

# %%
science_wales = science_tech_eng[science_tech_eng.Country == 'Wales']
science_wales.head()

# %%
science_england = science_tech_eng[science_tech_eng.Country == 'England']
science_england.head()

# %%
science_scotland = science_tech_eng[science_tech_eng.Country == 'Scotland']
science_scotland.head()

# %%
science_ireland = science_tech_eng[science_tech_eng.Country == 'Northern Ireland']
science_ireland.head()

# %%
ax = sns.barplot(x = 'Date', y = '21 Science, research, engineering and technology professionals', data = science_tech_eng, hue='Country')

# %%
ax = sns.barplot(x = 'Date', y = '21 Science, research, engineering and technology professionals', data = science_wales, hue='Country')

# %%
ax = sns.barplot(x = 'Date', y = '21 Science, research, engineering and technology professionals', data = science_scotland, hue='Country')

# %%
ax = sns.barplot(x = 'Date', y = '21 Science, research, engineering and technology professionals', data = science_ireland, hue='Country')

# %%
ax = sns.barplot(x = 'Date', y = '21 Science, research, engineering and technology professionals', data = science_england, hue='Country')

# %%
from scipy.stats import chi2_contingency
from scipy.stats import chi2

# %%
wales_df = wales_df.drop('Country',axis = 1)
wales_df.head()

# %%
stat,p,dof,expected = chi2_contingency(wales_df)

# %%
alpha = 0.05
print("p value is " + str(p))
if p <= alpha:
    print('Dependent (reject H0)')
else:
    print('Independent (H0 holds true)')

# %%
#The aim of the test is to show if the years are dependent on each other.
